# %% [markdown]
# # Data Merging - Scopus and SciVal
#
# This notebook merges Scopus and SciVal datasets using the EID column.
#
# ## Objectives:
# 1. Load both datasets
# 2. Merge using EID as key
# 3. Add abstracts from Scopus to SciVal entries
# 4. Resolve duplicate columns
# 5. Save merged dataset

# %%
import sys
sys.path.append('../')

import pandas as pd
from pathlib import Path

from src.data.load_data import load_scopus_data, load_scival_data
from src.data.merge_data import (
    add_abstracts_to_scival,
    resolve_duplicate_columns
)

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Load Data

# %%
# Load data files
SCOPUS_FILE = '../data/raw/scopus.csv'
SCIVAL_FILE = '../data/raw/scival.csv'

# Load datasets
scopus_df = load_scopus_data(SCOPUS_FILE)
scival_df = load_scival_data(SCIVAL_FILE)

print(f"Scopus: {scopus_df.shape}")
print(f"SciVal: {scival_df.shape}")

# %% [markdown]
# ## 2. Merge Datasets and Replace Abstracts
#
# SciVal's Abstract column contains URLs, not actual text. We use a left join to preserve all SciVal records and add real abstracts from Scopus where available.

# %%
# Add abstracts from Scopus to SciVal using a left join to preserve all SciVal records
merged_df = add_abstracts_to_scival(
    scival_df=scival_df,
    scopus_df=scopus_df,
    eid_column='EID',
    abstract_column='Abstract'
)

# Report match coverage and how many records could not be matched
matched = merged_df['Abstract'].notna().sum()
unmatched = merged_df['Abstract'].isna().sum()
print(f"Merged dataset shape: {merged_df.shape}")
print(f"Abstracts matched:    {matched} / {len(merged_df)}")
print(f"Abstracts unmatched:  {unmatched} / {len(merged_df)} (records kept, abstract is NaN)")

# %% [markdown]
# ## 3. Resolve Duplicate Columns
#
# After merging, some columns may have `_scopus` / `_scival` suffixes if they existed in both sources. Resolve them by prioritising Scopus values.

# %%
duplicate_cols = [col for col in merged_df.columns if col.endswith('_scopus') or col.endswith('_scival')]
print(f"Duplicate columns found: {len(duplicate_cols)}")
if duplicate_cols:
    print(duplicate_cols)
    merged_df = resolve_duplicate_columns(merged_df, priority='scopus')
    print(f"Columns after resolution: {len(merged_df.columns)}")
else:
    print("No duplicate columns to resolve.")

# %% [markdown]
# ## 4. Verify Merged Data

# %%
# Check key columns are present
key_cols = ['EID', 'Abstract', 'Title', 'Citations', 'Authors', 'Year']
print("Key columns check:")
for col in key_cols:
    status = '\u2713' if col in merged_df.columns else '\u2717'
    print(f"  {status} {col}")

# Check for duplicate EIDs
dup_eids = merged_df['EID'].duplicated().sum()
print(f"\nDuplicate EIDs: {dup_eids}")

# Null rates for key columns
print("\nNull rates for key columns:")
for col in key_cols:
    if col in merged_df.columns:
        null_pct = merged_df[col].isna().mean() * 100
        print(f"  {col}: {null_pct:.1f}% null")

# %% [markdown]
# ## 5. Examine Merged Data

# %%
print(f"Abstracts present: {merged_df['Abstract'].notna().sum()} / {len(merged_df)}")
print(f"Missing abstracts: {merged_df['Abstract'].isna().sum()}")
print(f"\nSample abstract:\n{merged_df['Abstract'].dropna().iloc[0][:200]}...")

# %% [markdown]
# ## 6. Save Merged Dataset

# %%
OUTPUT_DIR = Path('../data/processed')
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

OUTPUT_FILE = OUTPUT_DIR / 'merged.csv'
OUTPUT_PKL = OUTPUT_DIR / 'merged_data.pkl'
merged_df.to_csv(OUTPUT_FILE, index=False)
merged_df.to_pickle(OUTPUT_PKL)
print(f"Saved merged dataset to: {OUTPUT_FILE}")
print(f"Saved pickle to: {OUTPUT_PKL}")
print(f"Shape: {merged_df.shape}")

# %% [markdown]
# ## Summary Statistics

# %%
print("=" * 50)
print("MERGE SUMMARY")
print("=" * 50)
print(f"Total records: {len(merged_df)}")
print(f"Total columns: {len(merged_df.columns)}")
print(f"Memory usage: {merged_df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
print(f"\nKey columns present:")
key_cols = ['EID', 'Abstract', 'Title', 'Citations', 'Authors', 'Year']
for col in key_cols:
    if col in merged_df.columns:
        print(f"  \u2713 {col}")
    else:
        print(f"  \u2717 {col}")
